# %%
import collections
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')

from argparse import Namespace
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\joshw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\joshw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
args = Namespace(
    raw_dataset_csv="data/stock/stock_data.csv",
    train_proportion=0.7,
    val_proportion=0.15,
    test_proportion=0.15,
    output_munged_csv="data/stock/stock_data_split.csv",
    seed=1337
)

# %%
# Read raw data
news = pd.read_csv(args.raw_dataset_csv, header=0)
news = news.dropna()

replacement_mapping = {-1: 'negative', 1: 'positive'}

# Use the replace method to create a new column with replaced values
news['Sentiment'] = news['Sentiment'].replace(replacement_mapping)
news['Sentence'] = news['Text']
news = news[['Sentiment','Sentence']]

news.head()
# Out:
#                                                 Text  Sentiment
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1  user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2  user I'd be afraid to short AMZN - they are lo...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1

# %%
# Unique classes
set(news.Sentiment)
# Out:
# {'negative', 'positive'}

# %%
# Splitting train by category
# Create dict
by_category = collections.defaultdict(list)
for _, row in news.iterrows():
    by_category[row.Sentiment].append(row.to_dict())

# %%
by_category
# Out:
# defaultdict(list,
#             {'negative': [{'Sentiment': 'negative',
#                'Sentence': 'According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing '},
#               {'Sentiment': 'negative',
#                'Sentence': "At the request of Finnish media company Alma Media 's newspapers , research manager Jari Kaivo-oja at the Finland Futures Research Centre at the Turku School of Economics has drawn up a future scenario for Finland 's national economy by using a model developed by the University of Denver "},
#               {'Sentiment': 'negative',
#                'Sentence': 'STOCK EXCHANGE ANNOUNCEMENT 20 July 2006 1 ( 1 ) BASWARE SHARE SUBSCRIPTIONS WITH WARRANTS AND INCREASE IN SHARE CAPITAL A total of 119 850 shares have been subscribed with BasWare Warrant Program '},
#               {'Sentiment': 'negative',
#                'Sentence': 'A maximum of 666,104 new shares can further be subscribed for by exercising B options under the 2004 stock option plan '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Tiimari operates 194 stores in six countries -- including its core Finnish market -- and generated a turnover of 76.5 mln eur in 2005 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Finnish Talvivaara Mining Co HEL : TLV1V said Thursday it had picked BofA Merrill Lynch and JPMorgan NYSE : JPM as joint bookrunners of its planned issue of convertible notes worth up to EUR250m USD332m '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The mall is part of the Baltic Pearl development project in the city of St Petersburg , where Baltic Pearl CJSC , a subsidiary of Shanghai Foreign Joint Investment Company , is developing homes for 35,000 people '},
#               {'Sentiment': 'negative',
#                'Sentence': '4 ) Complete name of the shareholder : Otto Henrik Bernhard Nyberg 5 ) Further information : The amount of shares now transferred corresponds to 5.68 % of the total number of shares in Aspo Plc. '},
#               {'Sentiment': 'negative',
#                'Sentence': 'A data processing unit collects the data , calculates RVR values and provides the data to users via various interfaces '},
#               {'Sentiment': 'negative',
#                'Sentence': "German Commerzbank AG 's Hamburg Branch and US JP Morgan ( NYSE : JPM ) participated as arrangers , and Dutch ING ( AMS : INGA ) as co-arranger "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Increase in the number of shares is based on the option rights which were granted to the management of the company under the stock option plan 2006 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'It has some 30 offices worldwide and more than 90 pct of its net sales are generated outside Finland '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Nokia Messaging 1.1 enables customers to receive e-mails from up to 10 e-mail accounts on their mobile phone supporting all POP or IMAP e-mail services '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The contract value amounts to about EUR11m , the company added '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Aldata said that there are still a number of operational aspects to be defined between it and Microsoft and further details of the product and market initiatives resulting from this agreement will be available at a later date '},
#               {'Sentiment': 'negative',
#                'Sentence': 'ALEXANDRIA , Va. , May 16 -- Kenneth Bower of Vista , Calif. , has developed an ornamental design for a handset , the U.S. Patent & Trademark Office announced '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Biohit Oyj develops , manufactures and markets liquid handling products and diagnostic test systems for use in research , healthcare and industrial laboratories '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Mr Ashley , deputy executive chairman of Sports Direct , sold a 43pc stake in the company for more than pounds 900m at the time of the float '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Rental of building equipment accounted for 88 percent of the operating income '},
#               {'Sentiment': 'negative',
#                'Sentence': "Ruukki 's delivery includes steel structures , including installation , for Krakeroy bascule bridge and steel piles for the bridge foundations "},
#               {'Sentiment': 'negative',
#                'Sentence': "Stockmann was established in 1862 in Finland and it became the first foreign company to enter Russia 's retail trade market in 1989 "},
#               {'Sentiment': 'negative',
#                'Sentence': "The broad-based WIG index ended Thursday 's session 0.1 pct up at 65,003.34 pts , while the blue-chip WIG20 was 1.13 down at 3,687.15 pts "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The business to be divested generates consolidated net sales of EUR 60 million annually and currently has some 640 employees '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The company generates net sales of about 600 mln euro $ 775.5 mln annually and employs 6,000 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The contract covers the manufacturing , surface-treatment and installation of the steel structures '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The order also includes start-up and commissioning services '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The phones are targeted at first time users in growth markets '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Tielinja generated net sales of 7.5 mln euro $ 9.6 mln in 2005 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Tikkurila Powder Coatings has some 50 employees at its four paint plants , which generated revenues of EUR2 .4 m USD3 .3 m in 2010 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Under the rental agreement , Stockmann was committed to invest in the building of a bridge over the Gogol Street or build an underground tunnel for crossing the street by 2004 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'VNH generates annual net sales of about 5 mln eur and employs 21 people '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Jan. 6 -- Ford is struggling in the face of slowing truck and SUV sales and a surfeit of up-to-date , gotta-have cars '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Pharmaceuticals group Orion Corp reported a fall in its third-quarter earnings that were hit by larger expenditures on R&D and marketing '},
#               {'Sentiment': 'negative',
#                'Sentence': 'However , the growth margin slowed down due to the financial crisis '},
#               {'Sentiment': 'negative',
#                'Sentence': "Following this increase Huhtamaki 's registered share capital is EUR360 .62 m and the number of shares outstanding is 106,063,320 "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Helsinki on October 22 , 2008 SSH COMMUNICATIONS SECURITY CORP Board of Directors For further information , please contact : Tomi Laamanen , Chairman , tel. +358 0 400 609 544 Distribution : NASDAQ OMX Helsinki Ltd. '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The offer of some 30 million shares aimed to raise more than  x20ac 500 million US$ 640 million , was expected to be completed by Oct. 9 , Outokumpu said '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The original contract was signed last summer '},
#               {'Sentiment': 'negative',
#                'Sentence': '2009 3 February 2010 - Finland-based steel maker Rautaruukki Oyj ( HEL : RTRKS ) , or Ruukki , said today it slipped to a larger-than-expected pretax loss of EUR46m in the fourth quarter of 2009 from a year-earlier profit of EUR45m '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Result before taxes decreased to nearly EUR 14.5 mn , compared to nearly EUR 20mn in the previous accounting period '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The company slipped to an operating loss of EUR 2.6 million from a profit of EUR 1.3 million '},
#               {'Sentiment': 'negative',
#                'Sentence': '23 April 2010 - Finnish construction and engineering company Outotec Oyj HEL : OTE1V said today it slipped to a net loss of EUR7 .3 m in the first quarter of 2010 from a net profit of EUR12 .5 m in the corresponding period last year '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Cramo slipped to a pretax loss of EUR 6.7 million from a pretax profit of EUR 58.9 million '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from a profit of EUR 845,000 in the corresponding period a year earlier '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In 2009 , Comptel slipped to a net loss of EUR2 .1 m from a profit of EUR6 .6 m in the previous year '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In Q2 of 2009 , profit before taxes amounted to EUR 13.6 mn , down from EUR 26.8 mn in Q2 of 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'ADPnews - Feb 5 , 2010 - Finnish real estate investor Sponda Oyj HEL : SDA1V said today that it slipped to a net loss of EUR 81.5 million USD 11.8 m in 2009 from a profit of EUR 29.3 million in 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Profit before taxes amounted to EUR 56.5 mn , down from EUR 232.9 mn a year ago '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Profit before taxes decreased by 9 % to EUR 187.8 mn in the first nine months of 2008 , compared to EUR 207.1 mn a year earlier '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Profit before taxes decreased to EUR 31.6 mn from EUR 50.0 mn the year before '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Profit before taxes was EUR 4.0 mn , down from EUR 4.9 mn '},
#               {'Sentiment': 'negative',
#                'Sentence': "The company 's profit before taxes fell to EUR 21.1 mn in the third quarter of 2008 , compared to EUR 35.8 mn in the corresponding period in 2007 "},
#               {'Sentiment': 'negative',
#                'Sentence': '11 August 2010 - Finnish measuring equipment maker Vaisala Oyj HEL : VAIAS said today that its net loss widened to EUR4 .8 m in the first half of 2010 from EUR2 .3 m in the corresponding period a year earlier '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Finnish power supply solutions and systems provider Efore Oyj said its net loss widened to 3.2 mln euro $ 4.2 mln for the first quarter of fiscal 2006-2007 ending October 31 , 2007 from 900,000 euro $ 1.2 mln for the same period of fiscal 2005-06 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Elcoteq group recently announced that the last three months of the previous year brought to it a major loss of more than half a billion kroons ( EUR 32 mln ) for the fifth quarter running '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Cash Flow from Operations for the most recent quarter also reached a eight year low '},
#               {'Sentiment': 'negative',
#                'Sentence': "Shareholder 's full name and ID code : - Petri Ailus , born 15.9.1966 For further information , please contact Isto Hantila , CEO , tel. +358 9 591 8342 "},
#               {'Sentiment': 'negative',
#                'Sentence': 'At this growth rate , paying off the national debt will be extremely painful '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Simultaneously , his responsibility area is extended from legal affairs to cover also mergers and acquisitions '},
#               {'Sentiment': 'negative',
#                'Sentence': "Once your plants are in the ground they will continue to grow , but the success of any garden lies in how well it 's maintained "},
#               {'Sentiment': 'negative',
#                'Sentence': "Poyry 's contract includes engineering management , civil and detail engineering services , and time scheduling and procurement services "},
#               {'Sentiment': 'negative',
#                'Sentence': "Addus ' services include personal care and assistance with activities of daily living , skilled nursing and rehabilitative therapies , and adult day care "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Aldata Solution Oyj Bertrand Sciard President and CEO Further information : Aldata Solution Oyj , Bertrand Sciard , President and CEO , tel. +33 1 46 48 28 00 Aldata 100 % Retail-Wholesale At Aldata 100 % of our business is dedicated to retail and wholesale business improvement '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Alfa group will have 43.9 % of voting stock in the new company and Telenor 35.4 % with a free float of 20.7 % '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Altogether 150 subjects with mildly elevated cholesterol levels participated in the four-month long intervention '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Arto Ryymin , born 1964 , will replace Juhani Kaisanlahti who has worked as acting EVP , Healthcare & Welfare since August 2007 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'At CapMan Haavisto will be responsible for Group Finances and Accounting and IT '},
#               {'Sentiment': 'negative',
#                'Sentence': "Cablevision Systems Corp. CVC Their Madison Square Garden division owns and operates the New York Knickerbockers basketball team ; they also own the Madison Square Garden Arena , the New York Rangers hockey team , the New York Liberty women 's basketball team , and the Hartford Wolf Pack hockey team "},
#               {'Sentiment': 'negative',
#                'Sentence': 'CapMan has six investment areas CapMan Buyout , CapMan Technology , CapMan Life Science , CapMan Russia , CapMan Public Market and CapMan Real Estate , and each of them has a dedicated team and funds '},
#               {'Sentiment': 'negative',
#                'Sentence': 'CapMan Plc Press Release 31 March 2008 Jukka Ruuska , President of the OMX Nordic Exchanges and the Stockholm Stock Exchange , will transfer to CapMan effective no later than September 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'cents The profile contains business operations , the company history , major products and services , prospects , key competitors , structure and key employees , locations and subsidiaries '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Conference Call To participate via a conference call , please dial in 5-10 minutes before the beginning of the event : +44 0 20 7162 0025 Europe or +1 334-á323-á6201 USA '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Construction is scheduled to start in April-June 2007 and to be completed in early 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Founded in 1946 , Strand Associates , which provides civil , environmental , transportation , electrical and mechanical engineering services , has 350 employees at 10 offices in Wisconsin , Alabama , Illinois , Indiana , Kentucky and Ohio '},
#               {'Sentiment': 'negative',
#                'Sentence': "Halonen 's office acknowledged receiving the letter but declined comment "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Headquartered in this city , the company is nearly 75 years old and focuses on science-based innovation and technology for environmental measurement '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In 2009 , Lee & Man had a combined annual production capacity of close to 4.5 million tonnes of paper and 300,000 tonnes of pulp '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In the method the smelt spouts 2 are separated from the working area 6 by a shielding wall 8 , 10 arranged movable in relation to the smelt spouts '},
#               {'Sentiment': 'negative',
#                'Sentence': "It is necessary to strengthen the company 's operations , however "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Le Lay succeeds Walter G++nter and will be based in Finland '},
#               {'Sentiment': 'negative',
#                'Sentence': "Lemminkainen Infra Oy 's subsidiary Lemminkainen Sverige AB will perform the construction work , which is expected to start in early 2011 and to be completed in the summer of 2013 "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Los Angeles-based Pacific Office Properties Trust acquires , owns , and operates office properties in the western U.S. , focusing initially on the markets of Honolulu , San Diego , Los Angeles , and Phoenix '},
#               {'Sentiment': 'negative',
#                'Sentence': "Mr. Mikko Saavalainen , head of Comptel 's Global Sales concludes : `` Gibtelecom provides a perfect illustration of the variety of business , technical and regulatory challenges operators are facing in their OSS today "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Professional and consumer applications include personal navigation , personal safety , field and workflow management , and asset tracking '},
#               {'Sentiment': 'negative',
#                'Sentence': "Satama and Trainers ' House will remain as names and independent brands of the business areas "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The above mentioned shareholders will suggest that a monthly salary of EUR 1,400 would be paid for the Board members outside the company '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The address location is provided to a local controller , preferably by wireless transmission , which then uses the address location to access the appliance control module '},
#               {'Sentiment': 'negative',
#                'Sentence': "The Bank is also examining the benefits of transferring the Swedish business to operate as a branch office so that the operations would be governed by Finland 's laws "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The donations are granted to Aalto University and the universities of Helsinki , Tampere , Turku , Eastern Finland , Jyv+ñskyl+ñ , Oulu and Vaasa , and to polytechnics to be announced later '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The guidance has been set at 90 basis points over mid-swaps , the report said '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The invention carries International Patent Publication No. '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The inventors are Bylander Johan , Ponten Fredrik and Lundberg Jorgen '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The inventors are Mukkavilli Krishna Kiran , Sabharwal Ashutosh and Aazhang Behnaam '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Inventors are Ridge Justin , Bao Yiliang and Karczewicz Marta '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The issuer is solely responsible for the content of this announcement '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The market making in accordance with the agreement will begin on September 24 , 2009 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The offer price is $ 35 million , including cash of $ 10 million as net debt assumption of FACE , and $ 20 million worth of Cencorp shares to be issued to Savcor '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The original patent was filed in Finland under application No. '},
#               {'Sentiment': 'negative',
#                'Sentence': "The Swedish subsidiary holds 1.0 % net smelter return `` NSR '' royalties over two advanced copper projects in northern Sweden - the Viscaria and Adak Projects - being developed by Avalon Minerals Ltd. ASX : AVI "},
#               {'Sentiment': 'negative',
#                'Sentence': "The total investment in the Vantaa plant extension will amount to around 10 million euro , and Okmetic 's share of the investments will be worth around 2.7 million "},
#               {'Sentiment': 'negative',
#                'Sentence': 'You need to be ready when the window opens up , Rosberg said '},
#               {'Sentiment': 'negative',
#                'Sentence': '`` The issues identified by Stonesoft affect a range of content inspection technology '},
#               {'Sentiment': 'negative',
#                'Sentence': '`` They want my credit card info and my personal details '},
#               {'Sentiment': 'negative',
#                'Sentence': 'About Dopplr Dopplr is a service for smart travellers '},
#               {'Sentiment': 'negative',
#                'Sentence': "According to Sweden 's Minister for Local Government and Financial Markets , Mats Odell , the decision to sell the State 's shares in telecom group TeliaSonera can only be carried out in cooperation with the State of Finland "},
#               {'Sentiment': 'negative',
#                'Sentence': "According to CapMan Plc 's Corporate Governance , the majority of the committees ' members shall be independent of the Company "},
#               {'Sentiment': 'negative',
#                'Sentence': 'According to Finnair Technical Services , the measure is above all due to the employment situation '},
#               {'Sentiment': 'negative',
#                'Sentence': "According to Honka Japan 's Managing Director Marko Saarelainen , Honkarakenne exports about 200 ready made log houses to Japan a year "},
#               {'Sentiment': 'negative',
#                'Sentence': "According to preliminary data from Slovakia 's Statistics Office , goods worth E36 .4 million were imported from Finland between January and October 2010 , making up 0.1 percent of Slovakia 's total imports "},
#               {'Sentiment': 'negative',
#                'Sentence': 'According to Seikku , the retail sector in Finland is controlled by 3-4 large actors , while food manufacturers are still relatively small '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Also , a six-year historic analysis is provided for these markets '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Also , a six-year historic analysis is provided for this market '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Amanda said that it had already made a USD5 .0 m investment commitment in Russia Partners II fund in July 2005 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'An  of the invention , released by the Patent Office , said : `` The chambers are pressurized '},
#               {'Sentiment': 'negative',
#                'Sentence': "An audio webcast will be available live and archived on Cerner 's Web site at www.cerner.com "},
#               {'Sentiment': 'negative',
#                'Sentence': 'BasWare Order Matching automatically matches purchase invoices with approved purchase orders '},
#               {'Sentiment': 'negative',
#                'Sentence': "Capacity of the facility made by Finland 's Vaahto Group is 86,000 tons of light coated paper "},
#               {'Sentiment': 'negative',
#                'Sentence': 'CapMan , an asset manager , has EUR 3bn worth of assets under management in the Nordic region '},
#               {'Sentiment': 'negative',
#                'Sentence': 'CapMan has four investment areas ( CapMan Buyout , CapMan Technology , CapMan Life Science and CapMan Real Estate ) , and each of them has a dedicated team '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Castecka said the town hall would hold talks with other investors interested in the zone '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Changes being announced today will be effective after the close of trading on Friday , June 19 , 2009 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'CHS Expo Freight is a major Finnish fair , exhibition and culture logistics company that provides logistics services to various events by land , air and sea '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Competition authorities will have to approve the deal before it can be finalized '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Complete name of shareholder : Otto Henrik Bernhard Nyberg For further information , please contact Maija-Liisa Friman , CEO , tel. +358 9 7597 0711 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Completion of the transaction is subject to a final agreement and a Due Diligence process '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Construction is expected to be completed in the summer of 2011 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Dragonfly Love is another video shot from start to finish using the Nokia N8 '},
#               {'Sentiment': 'negative',
#                'Sentence': "Elcoteq 's Electronics Manufacturing Services ( EMS ) Business Segment serves customers globally in Engineering , Manufacturing and Fulfillment services "},
#               {'Sentiment': 'negative',
#                'Sentence': 'EQT has completed its exit from Salcomp , a Finnish company that makes mobile phone chargers , by selling its remaining stake to Swedish investment group Nordstjernan for about ( EURO ) 35 million ( $ 47 million ) '},
#               {'Sentiment': 'negative',
#                'Sentence': 'FinancialWire ( tm ) , in cooperation with the Investrend Broadcast Syndicate , also provides complete , daily conference call and webcast schedules as a service to shareholders and investors via the FirstAlert ( tm ) Networks oeFirstAlert ( tm ) Daily '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Following the registration , the number of issued and outstanding shares of Basware is 12,890,829 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Fortum had previously bought the state-held stake in TGK-10 from RAO UES during its reform '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Goodwill and other intangible assets account for some 2.0 mln euro ( $ 2.6 mln ) of the purchase price , 20 pct of which payable in Aspo shares '},
#               {'Sentiment': 'negative',
#                'Sentence': "Harold W. Young is an independent broker working closely with several retailers including Ahold USA , Market Basket , CVS , BJ 's Wholesale Club , Hannaford and Cumberland Farms "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Honkarakenne mainly exports large luxury log houses to Russia to be used as one-family houses or holiday homes ; 70 % of sales go to the Moscow region , about 20 % to the St Petersburg region , and the remainder to other locations '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In providing managed services , Nokia takes responsibility for building , operating and transferring as well as optimising the Indosat 3G network '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In today s business , you have to pre-empt what consumers want , said Mohammed Zainalabedin , General Manager , Zain Bahrain '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Insurance policies should be simple '},
#               {'Sentiment': 'negative',
#                'Sentence': 'It is a member of the OneWorld alliance , which includes American Airlines and British Airways '},
#               {'Sentiment': 'negative',
#                'Sentence': 'It is expected to be completed by the end of 2007 '},
#               {'Sentiment': 'negative',
#                'Sentence': "It will provide heating in the form of hot water for the sawmill 's needs "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Its 168 asset management experts manage assets worth over EUR 35 billion '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Jon Risfelt is 49 years old holds a Master of Science in Chemical Engineering from the Swedish Royal Institute of Technology '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Juha Haapakoski will continue as Editor-in-Chief with budget responsibility also with the new publisher '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Last July , the group said it intended to relocate warehouse and office space in Loudeac and Saint Marcel to Morvillars , in the east of France , where it already operates a hook manufacturing and distribution unit '},
#               {'Sentiment': 'negative',
#                'Sentence': 'LKAB , headquartered in Lulea , Sweden , is a high-tech mining company producing upgraded iron ore products for the steel industry '},
#               {'Sentiment': 'negative',
#                'Sentence': "Look out for vintage fabric cushion covers , '70s coffee pots , ceramic serving dishes , cocktail glasses , and stainless steel party dishes "},
#               {'Sentiment': 'negative',
#                'Sentence': 'National sponsors for The Big Read include National Endowment for the Arts in cooperation with the Institute of Museum and Library Services and Arts Midwest '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Neste Oil Corporation Refining Operation Asset Summary Report Summary Neste Oil Corporation Refining Operation Assets Summary Report is an essential source for company data and information '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Of these shares 14,747,084 are held by the Company and the number of outstanding shares and voting rights attached to the shares amounts thus to 161,256,847 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Oka specialises in new construction , renovation work of residential and non-residential building as well as premises for industrial and logistical use '},
#               {'Sentiment': 'negative',
#                'Sentence': "Okmetic Board of Directors has also decided on a new share ownership program directed to the company 's top management "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Panostaja , headquartered in Tampere , Finland , is an investment company focusing on small and medium-sized Finnish companies operating in the traditional industries '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Pertti Ervi is independent from the Company and its major shareholders '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Please inform IR Johanna Koskinen of your participation no later than 20 April at 10 a.m. A telephone conference for financial analysts and investors , conducted in English , will begin at 3:00 p.m. Finnish time ( EET ) '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Previously , the plant was expected to be completed by the end of 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Prothious Engineering ( www.prothious.com ) employs more than 1,000 and has a large portfolio of projects and an annual detailing capacity of more than 100,000 tonnes '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Rapala aims to move the distribution unit Ragot from Loudeac in Bretagne and the distribution unit Waterqueen and the fishing line supplier Tortue from Saint Marcel in Central France to Morvillars '},
#               {'Sentiment': 'negative',
#                'Sentence': 'RAPALA TOURNAMENT FISHING : With all the major titles already out for the holidays , bargain-priced games such as Rapala aim for a smaller audience '},
#               {'Sentiment': 'negative',
#                'Sentence': 'RFID ( Radio Frequency Identification ) is a method of so-called intelligent transport , whereby information can be read and saved remotely '},
#               {'Sentiment': 'negative',
#                'Sentence': "Sanoma also has an Executive Committee , in accordance with the Company 's Articles of Association , that prepares proposals for matters to be decided or noted by the Board of Directors "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Sarantel , based in Wellingborough , UK , designs high-performance antennas for portable wireless devices '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Shares will be acquired in accordance with section 5 of the rules of NASDAQ OMX Helsinki and other rules applicable to the acquisition of own shares '},
#               {'Sentiment': 'negative',
#                'Sentence': 'She will succeed Krister Kylas , who has decided to leave TeliaSonera '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Shuweihat 2 got under way in July 2008 when the project was awarded to desalination and power contractors '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Simmons Elected DCUC Chairman PORTSMOUTH , N.H.-Gordon A. Simmons , CEO of Service Credit Union , has been elected chairman of the Defense Credit Union Council for the 2007-2008 term '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Stock Exchange Release 10/3/2011 12:00 Sanoma has published its Annual Report and Financial Statements for 2010 and its first Corporate Responsibility Report '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Stockholm-based Nordea Bank ( STO : NDA ) said yesterday it had hired Casper von Koskull to lead its corporate merchant banking and capital markets unit , effective 1 September '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Swedish , Finnish and Danish listed companies are organized in three market cap segments , Nordic Large Cap , Mid Cap and Small Cap '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Symphony Services provides development services for Aldata GOLD '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Tekla provides 3D software for building and infrastructure engineering , with a focus on building information modelling of steel and concrete structures from design to construction '},
#               {'Sentiment': 'negative',
#                'Sentence': "Teleste 's hybrid TV solution includes components for the whole process of delivering video services to consumers from content acquisition and service creation to delivery through a range of access solutions , including HFC ( hybrid fibre-coaxial ) , xDSL , EttH , and FttH "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The agreement is valid for four years '},
#               {'Sentiment': 'negative',
#                'Sentence': "The broker started UPM-Kymmene , Stora Enso and Sappi with ` equal-weight ' recommendations and Holmen and Norske Skog with ` underweight ' ratings "},
#               {'Sentiment': 'negative',
#                'Sentence': "The business has sales of about ( Euro ) 35 million ( $ 44million ) , and has been responsible for sales and marketing of Lanxess 's paper chemicals business , which Kemira bought for ( Euro ) 88 million early this year ( CW , Jan. 11 , p. 22 ) "},
#               {'Sentiment': 'negative',
#                'Sentence': "The business section also includes Ahlstrom 's sustainability report "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The commission said the hydrogen peroxide and PBS market was worth about 470 million euros in 2000 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The company is presently examining whether the project would be financially feasible '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The company is studying the feasibility of focusing most of its processed meat production in the Vantaa facilities and the processing of fresh meat in the Forssa facilities '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The company specialises in temporary electrification and heating at construction sites '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The dividend is payable on February 1 , 2010 to shareholders of record on January 19 , 2010 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The EUR 0.7 million non-recurring expenses have been recorded for the third quarter '},
#               {'Sentiment': 'negative',
#                'Sentence': "The event can be followed on-line via Orion 's Finnish homepage at www.orion.fi as well as via the Kauppalehti Live web service at www.kauppalehti.fi/live "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Extraordinary General Meeting is expected to take place no later than 18 February 2011 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The first of the two project phases is expected to be completed by the end of 2012 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The group intends to relocate warehouse and office space in Loudeac and Saint Marcel to Morvillars , in the east of the country , where it already operates a hook manufacturing and distribution unit '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Group owns and operates a fleet of more than 800dwt , while container capacity is 17,000 TEUs , and manages a diversified fleet of its own railway rolling stock of over 17,000 units '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Hayward , Calif.-based target designs active , casual and dress footwear , as well as boots and sandals '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Lemminkainen Group , headquartered in Helsinki , Finland operates in all sectors of the construction industry : civil engineering , building contracting , technical building services and the building materials industry '},
#               {'Sentiment': 'negative',
#                'Sentence': "The Marubeni Group focuses on creating `` value chain '' from upstream to downstream , encompassing a wide variety of business fields , including oil & gas , metals , mineral resources , foods , pulp & paper and chemicals , among others "},
#               {'Sentiment': 'negative',
#                'Sentence': 'The new B shares carry the right to dividend and other shareholder rights with effect from today '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The office space will rise above the remodeled Cannon Street underground station '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The Oxyview Pulse Oximeter is a common device to check patient blood-oxygen saturation level and pulse rate '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The project is expected to be completed in 2009 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The reason for this is St. Petersburg status as a capital , one of the participants in the meeting quoted Chikunov as saying '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The report goes on to provide detailed profiles of ten leading European specialty chemicals companies , and brief profiles of other major players '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The report profiles 614 companies including many key and niche players worldwide such as Black & Decker Corporation , Fiskars Corporation , Fiskars Brands , Inc. , Husqvarna Outdoor Products Inc. , K+S Group , Ryobi Technologies , Inc. , The Scotts Miracle-Gro Company , and Van Group , Inc. '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The server is responsible for managing devices and user accounts and a desktop client application enables remote access to the mobile phones '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The share of the share capital of both above mentioned shareholders remains below 5 % '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The shares shall be repurchased through public trading , for which reason the shares are repurchased otherwise than in proportion to the holdings of the shareholders '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The subsidiary will be responsible for filter sales , local assembly of filters and after market services in China '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The total value of the project is valued at SEK 30bn ( EUR 2.83 bn USD 3.81 bn ) '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The trade is in accordance with the agreement announced on 26 March 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The transaction is expected to be completed next spring '},
#               {'Sentiment': 'negative',
#                'Sentence': 'The writing and publication of Lemmink+ñinen -¦ s history is a continuation of earlier collaboration between Antti Tuuri and the company '},
#               {'Sentiment': 'negative',
#                'Sentence': 'These products include Personal Communications products such as mobile phones and their parts , Home Communications products such as set-top boxes and electronics for flat panel TVs as well as Communications Networks products such as base-stations , tower-top amplifiers , and microwave systems '},
#               {'Sentiment': 'negative',
#                'Sentence': 'To check them out or to make a bid they will be in the Deka Showroom , Fortitude Valley '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Uponor maintains its full-year guidance for 2010 '},
#               {'Sentiment': 'negative',
#                'Sentence': "Utah 's capital wanted to be the next U.S. headquarters of Amer Sports Corp. , a ski-equipment company "},
#               {'Sentiment': 'negative',
#                'Sentence': 'When completed , the 120-meter Watchtower will be the highest building in Ireland '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Viking will pay EUR 130 million for the new ship , which will be completed in January 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': "ASSA ABLOY Kaupthing Bank gave a ` neutral ' recommendation and a share price target of 174 crowns $ 24.7 - 19 euro on Swedish lock maker Assa Abloy AB "},
#               {'Sentiment': 'negative',
#                'Sentence': '`` Our aim is to understand different traffic patterns based on the use of each building '},
#               {'Sentiment': 'negative',
#                'Sentence': '`` Our Vaalipalvelu-service was especially developed for use by communities and organizations '},
#               {'Sentiment': 'negative',
#                'Sentence': "`` The industry is coming to an interesting fork in the road as both handset manufacturers and wireless carriers attempt to serve as the portal for Web-based service to your wireless handset , '' he wrote "},
#               {'Sentiment': 'negative',
#                'Sentence': '18:30 Dinner The conference program can also be viewed as a live audio webcast through the internet pages at www.citycon.com '},
#               {'Sentiment': 'negative',
#                'Sentence': 'A PLUMBING business has announced it is sponsoring a professional darts player '},
#               {'Sentiment': 'negative',
#                'Sentence': 'A. Le Coq Special was developed for the bicentenary of the company and the trade mark , the brewer said '},
#               {'Sentiment': 'negative',
#                'Sentence': "Another noticeable thing is that the search for Tata and Airtel brands was mostly related to ` broadband connections ' "},
#               {'Sentiment': 'negative',
#                'Sentence': "Aspo has also investigated the sales opportunities of Kaukomarkkinat 's electronics business "},
#               {'Sentiment': 'negative',
#                'Sentence': 'At the beginning of the subscription period on May 2 , 2006 the share subscription price under B option right is EUR 10.22 per share '},
#               {'Sentiment': 'negative',
#                'Sentence': "Both Mr Walden and Mr Ignatius will be responsible also for the newspapers ' business result "},
#               {'Sentiment': 'negative',
#                'Sentence': 'Capitex Kalmar will continue to be responsible for the maintenance and technical development of the services '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Changes to the as-built models from the design were communicated to the subcontractors to accommodate them into the steel and GRC glass reinforced concrete fabrication process '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Customers in a wide range of industries use our stainless steel and services worldwide '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Exel wants to serve its industrial customers with individual products '},
#               {'Sentiment': 'negative',
#                'Sentence': 'Finnish bank Pohjola Bank Plc HEL : POH1S said today that it will issue a EUR 40 million USD 51.2 m index-linked bond , Pohjola Tutkimuksen Tahdet VIII-2010 Pohjola Research Stars VIII-2010 , on October 27 , 2010 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'From Merisatama to the far corners of the world Asfaltti Osakeyhti+Â Lemmink+ñinen was established in 1910 by a group of master builders in Helsinki as a specialist business and subcontractor '},
#               {'Sentiment': 'negative',
#                'Sentence': 'F-Secure , a developer of security solutions as a service through Internet Service Providers and mobile operators , announced results from its annual Online Wellbeing Survey '},
#               {'Sentiment': 'negative',
#                'Sentence': 'In 2008 , Kemira recorded revenue of approximately EUR 2.8 billion and had a staff of 9,400 '},
#               {'Sentiment': 'negative',
#                'Sentence': "In accordance with the terms and conditions of Alma Media 's 2006 option program , the share subscription price for the 2006A option rights was EUR 4.88 per share and the book countervalue EUR 0.60 per share "},
#               {'Sentiment': 'negative',
#                'Sentence': "In Penttil+ñ 's vision , the most important reason for the transaction is Russia "},
#               {'Sentiment': 'negative',
#                'Sentence': 'It also confirmed its earnings guidance for the whole 2009 issued in its report for the whole 2008 '},
#               {'Sentiment': 'negative',
#                'Sentence': 'It is hand-painted resin with real 14-0 trebles and is 75cm long by 25cm deep from top to bottom of the middle hook '},
#               {'Sentiment': 'negative',
# ...
#               {'Sentiment': 'positive',
#                'Sentence': 'Aspocomp has repaid its interest bearing liability to Standard Chartered Bank and will use the rest of the consideration to partially repay its interest bearing liabilities in Finland and to improve its liquidity .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Tim Cockroft brings with him an excellent track record having more than 18 years experience ; moreover , Tim has successfully developed the Capital Markets operations at Kaupthing Singer & Friedlander involving corporate finance and broking with a focus on mid-market companies .'},
#               {'Sentiment': 'positive',
#                'Sentence': "The company 's net profit rose 11.4 % on the year to 82.2 million euros in 2005 on sales of 686.5 million euros , 13.8 % up on the year , the company said earlier ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'A purchase agreement for 7,200 tons of gasoline with delivery at the Hamina terminal , Finland , was signed with Neste Oil OYj at the average Platts index for this September plus eight US dollars per month .'},
#               {'Sentiment': 'positive',
#                'Sentence': '$PKT Momentum building for breakout trigger ! Long setup http://stks.co/eXVU'},
#               {'Sentiment': 'positive',
#                'Sentence': 'By cutting the number of plants , the group will trim fixed costs .'},
#               {'Sentiment': 'positive',
#                'Sentence': "Merkel's Government Said to Support Deutsche Boerse-LSE Merger"},
#               {'Sentiment': 'positive',
#                'Sentence': 'President and CEO Mika Vehvil+ñinen says the positive signs are first and foremost emerging outside Finland .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Finnish construction group Lemmink+ñinen has been awarded two road building contracts by the Lithuanian transport administration .'},
#               {'Sentiment': 'positive',
#                'Sentence': '$RAD I would consider this opportunity to add my position because the company is on the right track they are still improving sales...'},
#               {'Sentiment': 'positive',
#                'Sentence': "Progress Group , QPR 's representative in Saudi Arabia and North Africa , has signed a framework agreement for a long term strategic relationship with ISE ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'RECAP: $MSFT rumor this morning had them spinning off XBOX unit, stock grinds up all day to close on highs'},
#               {'Sentiment': 'positive',
#                'Sentence': "According to Finnish Metso Minerals , the value of the company 's orders has gone up to EUR 1.9 bn in 12 months ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Breakingviews: IAG can pay more for Aer Lingus'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Based upon its unique fiber expertise and innovative approach , the company has a strong market position in several business areas in which it operates .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Aviva weighs cash handout after beating profit forecast'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Finnish and Swedish construction markets are still experiencing an estimated 4 % annual growth in 2008 .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'After the takeover , Cramo will become the second largest rental services provider in the Latvian market .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'It projected revenue of $ 2.2 billion to $ 2.3 billion , slightly higher than analyst estimates of $ 2.19 billion .'},
#               {'Sentiment': 'positive',
#                'Sentence': "The brokerage said 2006 has seen a ` true turning point ' in European steel base prices , with better pricing seen carrying through the second quarter of 2006 ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Operating profit totalled EUR 83.0 mn , up from EUR 23.5 mn year-on-year .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'BRIEF-Aviva aims to increase dividend pay-out ratio to 50 pct in 2017'},
#               {'Sentiment': 'positive',
#                'Sentence': '$EXPE working on the second leg of its reversal run as it breaks another down trend and continues higher. https://t.co/76DSJysyR0'},
#               {'Sentiment': 'positive',
#                'Sentence': "$ADBE technical alerts: Expansion Breakout, Gilligan's Island Sell Setup, Volume Surge, and New 52... https://t.co/LxX66tknFH"},
#               {'Sentiment': 'positive',
#                'Sentence': 'Operating profit improved by 27 % to EUR 579.8 mn from EUR 457.2 mn in 2006 .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Shire proposes $30 bln all-share tie-up with Baxalta'},
#               {'Sentiment': 'positive',
#                'Sentence': 'This transaction will also rationalize our pulp and paper industry related solutions .'},
#               {'Sentiment': 'positive',
#                'Sentence': "I am looking forward to contribute to SRV 's success with my competence '' , says Taneli Hassinen ."},
#               {'Sentiment': 'positive',
#                'Sentence': "AstraZeneca's MedImmune Inks Licensing Deal With Omnis Pharmaceuticals"},
#               {'Sentiment': 'positive',
#                'Sentence': 'Order intake grew by 40 % year-on-year and 30 % year-on-year , respectively , to EUR 576 million and EUR 1.7 billion for the respective January-September and July-September 2010 periods .'},
#               {'Sentiment': 'positive',
#                'Sentence': "Finnish OKO bank has signed a cooperation agreement with Raiffeisen concerning Finnish companies ' investments in Russia ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Exports grew 16.5 percent to 19.1 million liters .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Digia said its consolidated net sales for January-June 2010 were EUR67 .8 m , up 9.7 % on the same period in 2009 ( EUR61 .9 m ) .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'TRLPC - CRH backs Lafarge Holcim asset buy with 6.5 bln euro bridge loan'},
#               {'Sentiment': 'positive',
#                'Sentence': 'G4S sees profits rise but UK contract problems remain'},
#               {'Sentiment': 'positive',
#                'Sentence': 'In 2006 , Kone received an order from Aker Yards to supply 43 customised elevators for the very first Genesis cruise ship which is scheduled to be completed in 2009 .'},
#               {'Sentiment': 'positive',
#                'Sentence': "UPDATE 3-Auto Trader shares leap in UK's biggest private equity-backed listing"},
#               {'Sentiment': 'positive',
#                'Sentence': 'In the third quarter , net sales increased by 12 % year-on-year to EUR159 .5 m , or by 6 % at comparable currency rates growth .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'The fair value of the investment properties totaled EUR 2,534.9 mn , up from EUR 2,455.1 mn in 2006 .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Diluted EPS rose to EUR3 .68 from EUR0 .50 .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Long $VVUS shares as a call option w/ an expiration of..  umm.. TODAY.    Hitting HOD here.'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Raute Corporation has received orders worth over EUR 12 million from OOO Ilim Bratsk DOK in Russia .'},
#               {'Sentiment': 'positive',
#                'Sentence': "`` We 've been feeling quite positive about the region as a whole ."},
#               {'Sentiment': 'positive',
#                'Sentence': "CompaniesAB InBev signals it won't go hostile for SABMiller"},
#               {'Sentiment': 'positive',
#                'Sentence': "The ISO certification demonstrates that we are moving forward in our quality commitments to our customers . '"},
#               {'Sentiment': 'positive',
#                'Sentence': 'Significance : Teleste has emphasised that with its large size and growing economy , as well as the rapid development of its TV services distribution industry , Poland is viewed as an attractive market .'},
#               {'Sentiment': 'positive',
#                'Sentence': '( ADP News ) - Oct 31 , 2008 - Finnish food company Raisio Oyj ( OMX : RAIVV ) said today that its net profit jumped to EUR 16.4 million ( USD 20.9 m ) for the first nine months of 2008 from EUR 1.1 million for the same period of 2'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Sponda will record a profit from the sale of 8.5 mln euro ($ 12.4 mln).'},
#               {'Sentiment': 'positive',
#                'Sentence': '$TRX http://stks.co/1KkK Long setup. MACD cross.'},
#               {'Sentiment': 'positive',
#                'Sentence': "The Group 's business is balanced by its broad portfolio of sports and presence in all major markets ."},
#               {'Sentiment': 'positive',
#                'Sentence': '$SPY  still wants higher I think.'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Poyry has a good track record of major transportation projects in Latin America .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'These measures are expected to produce annual cost savings of EUR 1.5 million starting in 2007 .'},
#               {'Sentiment': 'positive',
#                'Sentence': "Sanoma Magazines Finland 's net sales grew to EUR 140.1 mn from EUR 131.8 mn ."},
#               {'Sentiment': 'positive',
#                'Sentence': "Ruukki 's order book at the end of 2010 was 30 % up year-on-year and 10 % up quarter-on-quarter ."},
#               {'Sentiment': 'positive',
#                'Sentence': "At the end of March 2007 , the group 's order book was at EUR 39.6 mn , up 42 % from the corresponding period in 2006 ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Metsaliitto said that it will book a minor gain of less than EUR1 .0 m from the transaction .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Known as Post Bank , the concept would see Fidelity Bank rolling out 75 offices in Ghana Post premises , to provide financial services to the people .'},
#               {'Sentiment': 'positive',
#                'Sentence': '$SONC Amazing run since middle of March - obvious that the quality/tastiness of their burgers is not being factored into this price advance'},
#               {'Sentiment': 'positive',
#                'Sentence': 'AstraZeneca shares climb 3% as drug maker ups profits forecasts'},
#               {'Sentiment': 'positive',
#                'Sentence': '- Operating profit rose by 26.9 % to EUR 105.8 ( 83.4 ) million .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'The EPS improved to EUR0 .38 from EUR0 .27 .'},
#               {'Sentiment': 'positive',
#                'Sentence': "Insight hires Aviva's David Hillier for multi-asset team"},
#               {'Sentiment': 'positive',
#                'Sentence': 'Today I bought more $MU $YHOO $VALE $NBL $TWTR $AXP $ZNGA https://t.co/Vt6T5Zp2is'},
#               {'Sentiment': 'positive',
#                'Sentence': "I'm liking the price action in $SWKS, currently @21.80 ; my target: 24.00+ before year end."},
#               {'Sentiment': 'positive',
#                'Sentence': "According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales ."},
#               {'Sentiment': 'positive',
#                'Sentence': "Dubai Nokia has announced the launch of `` Comes with Music '' , its ground-breaking service which introduces a new way for people to enjoy music ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Cost savings will then rise to some 20 mln eur a year from 2007 , OKO said .'},
#               {'Sentiment': 'positive',
#                'Sentence': "Biohit and VWR have been in close cooperation for a number of years in the US , where Biohit is one of VWR 's focus suppliers ."},
#               {'Sentiment': 'positive',
#                'Sentence': '$SPY Long 1/2 position 137.89'},
#               {'Sentiment': 'positive',
#                'Sentence': '( ADP News ) - Oct 1 , 2008 - Finnish consulting and engineering company Poyry Oyj ( OMX : POY1V ) said today it was awarded a EUR 5.2 million ( USD 7.4 m ) extension to their existing consultancy engineering contract with Venezuel'},
#               {'Sentiment': 'positive',
#                'Sentence': "In July-September 2008 , YIT 's net sales increased to EUR 970.8 mn , compared to EUR 906.8 mn in the corresponding period in 2007 ."},
#               {'Sentiment': 'positive',
#                'Sentence': "In Finland , insurance company Pohjola and the Finnish motorcyclist association have signed an agreement with the aim of improving motorcyclists ' traffic safety ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'The Department Store Division reported an increase in sales of 4 per cent .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Operating profit rose to EUR 103.4 mn from EUR 23.2 in the corresponding period in 2006 .'},
#               {'Sentiment': 'positive',
#                'Sentence': "In the second quarter of 2010 , the group 's net profit rose to EUR3 .1 m from EUR2 .5 m in April-June 2009 ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Exports accounted for 65.4 % of net sales , representing an all time record for the company .'},
#               {'Sentiment': 'positive',
#                'Sentence': "According to Nordic financial group Nordea 's analyst Sami Sarkamies , this makes Nokia 's portfolio competitive again ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'Finnish steel maker Rautaruukki Oyj ( Ruukki ) said on July 7 , 2008 that it won a 9.0 mln euro ( $ 14.1 mln ) contract to supply and install steel superstructures for Partihallsforbindelsen bridge project in Gothenburg , western Sweden .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Both operating profit and turnover for the six-month period increased , respectively , from EUR17 .6 m and EUR1149 .9 m , as compared to the corresponding period in 2007 .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Operating profit for the nine-month period increased from EUR3 .1 m and net sales increased from EUR61 .5 m , as compared to the corresponding period in 2007 .'},
#               {'Sentiment': 'positive',
#                'Sentence': '$NKE gapping up to all time highs http://stks.co/q1jAu #tradeideas http://stks.co/r1j6c'},
#               {'Sentiment': 'positive',
#                'Sentence': 'Elisa said mobile subscriptions grew 7 percent during 2007 , mainly because of customers adopting so-called third generation mobile technology .'},
#               {'Sentiment': 'positive',
#                'Sentence': 'SRV will raise its holding in the company so that by the summer of 2008 , it will have a majority .'},
#               {'Sentiment': 'positive',
#                'Sentence': "Olvi , which controls a 94 percent stake in Ragutis through A. Le Coq , said in its annual report published earlier this year that the Lithuanian brewery 's sales reached 15.04 million euros last year , a rise of 20.4 percent from 12.49 million euros in 2004 ."},
#               {'Sentiment': 'positive',
#                'Sentence': 'The fair value of the property portfolio doubled as a result of the Kapiteeli acquisition and totalled EUR 2,686.2 1,259.7 million .'},
#               ...]})

# %%
# Create split data
final_list = []
np.random.seed(args.seed)
for _, item_list in sorted(by_category.items()):
    np.random.shuffle(item_list)
    n = len(item_list)
    n_train = int(args.train_proportion*n)
    n_val = int(args.val_proportion*n)
    n_test = int(args.test_proportion*n)
    
    # Give data point a split attribute
    for item in item_list[:n_train]:
        item['split'] = 'train'
    for item in item_list[n_train:n_train+n_val]:
        item['split'] = 'val'
    for item in item_list[n_train+n_val:]:
        item['split'] = 'test'  
    
    # Add to final list
    final_list.extend(item_list)

# %%
# Write split data to file
final_news = pd.DataFrame(final_list)

# %%
final_news.split.value_counts()
# Out:
# split
# train    76124
# test     16315
# val      16311
# Name: count, dtype: int64

# %%
lemmatizer = WordNetLemmatizer()

# Define a set of stopwords
stop_words = set(stopwords.words("english"))

def preprocess_text(text):
   # Convert text to lowercase
    text = text.lower()    
    # Tokenize the text into words
    words = text.split()
    # Remove stopwords and perform lemmatization
    words = [word for word in words if word not in stop_words]
    # Join the words back into a single string
    text = ' '.join(words)
    # Add spaces before and after punctuation marks
    text = re.sub(r"([.,!?])", r" \1 ", text)    
    # Remove non-alphanumeric characters
    text = re.sub(r"[^a-zA-Z.,!?]+", r" ", text) 
    return text

final_news.Sentence = final_news.Sentence.apply(preprocess_text)
print(final_news["Sentence"].isna().sum())

final_news.dropna(subset=["Sentence"], inplace=True)
print(final_news["Sentence"].isna().sum())
# Out:
# 0
# 0

# %%
final_news.Sentiment.value_counts()
# Out:
# Sentiment
# positive    55724
# negative    53026
# Name: count, dtype: int64

# %%
final_news.head()
# Out:
#   Sentiment                                      Sentence  split
# 0  negative                             euro could affect  train
# 1  negative            audio diary immigration western us  train
# 2  negative                  wonder zamora eyed top clubs  train
# 3  negative                              letters , april   train
# 4  negative  archives show churchill ordered ufo cover up  train

# %%
# Write munged data to CSV
final_news.to_csv(args.output_munged_csv, index=False)
